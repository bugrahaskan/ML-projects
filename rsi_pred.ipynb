# %%
import pandas as pd
import numpy as np

data = pd.read_csv('data_sample.csv', index_col='date')
data = data.iloc[:, [4]]

# %%
data
# Out:
#                        close
# date
# 2024-01-26 08:35:00  2211.44
# 2024-01-26 08:36:00  2210.08
# 2024-01-26 08:37:00  2209.59
# 2024-01-26 08:38:00  2210.01
# 2024-01-26 08:39:00  2210.52
# ...                      ...
# 2024-01-29 09:58:00  2272.03
# 2024-01-29 09:59:00  2273.23
# 2024-01-29 10:00:00  2271.99
# 2024-01-29 10:01:00  2273.83
# 2024-01-29 10:02:00  2275.81
#
# [4408 rows x 1 columns]

# %%
from talib import RSI

data['rsi'] = RSI(data['close'])
data.dropna(axis=0, inplace=True)

# %%
data
# Out:
#                        close        rsi
# date
# 2024-01-26 08:49:00  2207.43  30.089374
# 2024-01-26 08:50:00  2209.03  40.303959
# 2024-01-26 08:51:00  2209.27  41.680433
# 2024-01-26 08:52:00  2208.23  37.631163
# 2024-01-26 08:53:00  2208.10  37.145378
# ...                      ...        ...
# 2024-01-29 09:58:00  2272.03  63.214638
# 2024-01-29 09:59:00  2273.23  66.968045
# 2024-01-29 10:00:00  2271.99  60.139397
# 2024-01-29 10:01:00  2273.83  65.724506
# 2024-01-29 10:02:00  2275.81  70.512540
#
# [4394 rows x 2 columns]

# %%
data['shift'] = data['rsi'].shift(-1)
data.dropna(axis=0, inplace=True)

# %%
data
# Out:
#                        close        rsi      shift
# date
# 2024-01-26 08:49:00  2207.43  30.089374  40.303959
# 2024-01-26 08:50:00  2209.03  40.303959  41.680433
# 2024-01-26 08:51:00  2209.27  41.680433  37.631163
# 2024-01-26 08:52:00  2208.23  37.631163  37.145378
# 2024-01-26 08:53:00  2208.10  37.145378  41.289187
# ...                      ...        ...        ...
# 2024-01-29 09:57:00  2271.71  62.149649  63.214638
# 2024-01-29 09:58:00  2272.03  63.214638  66.968045
# 2024-01-29 09:59:00  2273.23  66.968045  60.139397
# 2024-01-29 10:00:00  2271.99  60.139397  65.724506
# 2024-01-29 10:01:00  2273.83  65.724506  70.512540
#
# [4393 rows x 3 columns]

# %%
data['time_dummy'] = np.arange(1,len(data.index)+1)
data.set_index('time_dummy', inplace=True)

# %%
data
# Out:
#               close        rsi      shift
# time_dummy
# 1           2207.43  30.089374  40.303959
# 2           2209.03  40.303959  41.680433
# 3           2209.27  41.680433  37.631163
# 4           2208.23  37.631163  37.145378
# 5           2208.10  37.145378  41.289187
# ...             ...        ...        ...
# 4389        2271.71  62.149649  63.214638
# 4390        2272.03  63.214638  66.968045
# 4391        2273.23  66.968045  60.139397
# 4392        2271.99  60.139397  65.724506
# 4393        2273.83  65.724506  70.512540
#
# [4393 rows x 3 columns]

# %%
X_train = data.iloc[:4000, [0,1]]
y_train = data.iloc[:4000, 2]

# %%
X_test = data.iloc[4000:, [0,1]]
y_test = data.iloc[4000:, 2]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Reshape X_train to create sequences with 3999 time steps and 1 feature per time step
X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))

# Check the shape of the reshaped data
print("X_train_reshaped shape:", X_train_reshaped.shape)

# Similarly, reshape X_test if needed
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))
# Out:
# X_train_reshaped shape: (4000, 2, 1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential([
    LSTM(units=50, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])),
    Dense(units=1)
])
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# 2024-02-07 08:55:23.868113: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-07 08:55:23.942911: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-07 08:55:23.942993: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-07 08:55:23.946538: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-07 08:55:23.961937: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-07 08:55:26.146515: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model.fit(X_train_reshaped, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 3s 5ms/step - loss: 2525.3857
# Epoch 2/100
# 125/125 [==============================] - 1s 5ms/step - loss: 1452.9718
# Epoch 3/100
# 125/125 [==============================] - 1s 4ms/step - loss: 796.9080
# Epoch 4/100
# 125/125 [==============================] - 1s 6ms/step - loss: 509.9649
# Epoch 5/100
# 125/125 [==============================] - 1s 5ms/step - loss: 341.1531
# Epoch 6/100
# 125/125 [==============================] - 1s 6ms/step - loss: 239.2729
# Epoch 7/100
# 125/125 [==============================] - 1s 5ms/step - loss: 179.9339
# Epoch 8/100
# 125/125 [==============================] - 1s 7ms/step - loss: 147.2463
# Epoch 9/100
# 125/125 [==============================] - 1s 9ms/step - loss: 130.4896
# Epoch 10/100
# 125/125 [==============================] - 1s 6ms/step - loss: 122.5328
# Epoch 11/100
# 125/125 [==============================] - 1s 7ms/step - loss: 119.0243
# Epoch 12/100
# 125/125 [==============================] - 1s 8ms/step - loss: 117.6204
# Epoch 13/100
# 125/125 [==============================] - 1s 5ms/step - loss: 117.1014
# Epoch 14/100
# 125/125 [==============================] - 1s 6ms/step - loss: 116.9169
# Epoch 15/100
# 125/125 [==============================] - 1s 7ms/step - loss: 116.8779
# Epoch 16/100
# 125/125 [==============================] - 1s 7ms/step - loss: 116.8553
# Epoch 17/100
# 125/125 [==============================] - 1s 5ms/step - loss: 116.8475
# Epoch 18/100
# 125/125 [==============================] - 1s 6ms/step - loss: 116.8539
# Epoch 19/100
# 125/125 [==============================] - 1s 8ms/step - loss: 116.8454
# Epoch 20/100
# 125/125 [==============================] - 1s 6ms/step - loss: 116.8475
# Epoch 21/100
# 125/125 [==============================] - 1s 6ms/step - loss: 116.8539
# Epoch 22/100
# 125/125 [==============================] - 1s 6ms/step - loss: 116.8443
# Epoch 23/100
# 125/125 [==============================] - 1s 6ms/step - loss: 116.8650
# Epoch 24/100
# 125/125 [==============================] - 1s 5ms/step - loss: 116.8504
# Epoch 25/100
# 125/125 [==============================] - 1s 4ms/step - loss: 116.8479
# Epoch 26/100
# 125/125 [==============================] - 1s 4ms/step - loss: 116.8588
# Epoch 27/100
# 125/125 [==============================] - 1s 5ms/step - loss: 116.8715
# 125/125 [==============================] - 1s 4ms/step - loss: 19.5525
# Epoch 99/100
# 125/125 [==============================] - 1s 4ms/step - loss: 19.6650
# Epoch 100/100
# 125/125 [==============================] - 1s 5ms/step - loss: 19.5656

# %%
pred = model.predict(X_test_reshaped)
# Out:
# 13/13 [==============================] - 1s 2ms/step

# %%
pred_df = pd.DataFrame(pred)

# %%
test_df = pd.DataFrame(y_test)
test_df
# Out:
#                 shift
# time_dummy
# 4001        68.427926
# 4002        59.936649
# 4003        49.505921
# 4004        54.123375
# 4005        49.927132
# ...               ...
# 4389        63.214638
# 4390        66.968045
# 4391        60.139397
# 4392        65.724506
# 4393        70.512540
#
# [393 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

pred_df.plot()
test_df.plot()
plt.show()

# %%
# Plot the data from df1
plt.plot(np.arange(len(pred_df)), pred_df[0], label='DataFrame 1')

# Plot the data from df2 on the same graph
plt.plot(np.arange(len(test_df)), test_df['shift'], label='DataFrame 2')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Plotting Two DataFrames')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# Assuming y_true and y_pred are arrays of continuous values
mse = mean_squared_error(y_test, pred)

# %%
mse
# Out:
# 19.482769874873043

# %%
data_new = pd.read_csv('data_sample_new.csv', index_col='date')
data_new = data_new.iloc[:, [4]]

data_new['rsi'] = RSI(data_new['close'])
data_new.dropna(axis=0, inplace=True)

data_new['time_dummy'] = np.arange(1,len(data_new.index)+1)
data_new.set_index('time_dummy', inplace=True)

data_new
# Out:
#               close        rsi
# time_dummy
# 1           2207.43  30.089374
# 2           2209.03  40.303959
# 3           2209.27  41.680433
# 4           2208.23  37.631163
# 5           2208.10  37.145378
# ...             ...        ...
# 8562        2274.95  50.189853
# 8563        2274.31  46.626386
# 8564        2275.36  52.575516
# 8565        2275.87  55.188188
# 8566        2276.04  56.057215
#
# [8566 rows x 2 columns]

# %%
X_new = scaler.transform(data_new)

# Reshape X_train to create sequences with 3999 time steps and 1 feature per time step
X_new_reshaped = X_new.reshape((X_new.shape[0], X_new.shape[1], 1))

# %%
X_new
# Out:
# array([[0.01986625, 0.21950928],
#        [0.03560189, 0.35849957],
#        [0.03796223, 0.3772293 ],
#        ...,
#        [0.68794256, 0.52547917],
#        [0.6929583 , 0.56102991],
#        [0.69463021, 0.57285479]])

# %%
pred_new = model.predict(X_new_reshaped)
# Out:
# 268/268 [==============================] - 1s 2ms/step

# %%
pred_new
# Out:
# array([[33.796867],
#        [42.670082],
#        [43.916462],
#        ...,
#        [52.50112 ],
#        [54.986153],
#        [55.806637]], dtype=float32)

# %%
plt.rcParams['figure.figsize'] = (124, 8)

# Plot the data from df1
plt.plot(np.arange(len(pred_new)), pred_new, label='DataFrame 1')

# Plot the data from df2 on the same graph
plt.plot(np.arange(len(data_new)), data_new['rsi'], label='DataFrame 2')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Plotting Two DataFrames')

# Add legend
plt.legend()

# Show the plot
plt.show()
