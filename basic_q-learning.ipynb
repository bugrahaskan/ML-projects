# %%
import numpy as np

class QLearningAgent:
    def __init__(self, num_states, num_actions, learning_rate=0.1, discount_factor=0.9, exploration_rate=0.1):
        self.num_states = num_states
        self.num_actions = num_actions
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.exploration_rate = exploration_rate
        self.q_table = np.zeros((num_states, num_actions))

    def select_action(self, state):
        # Epsilon-greedy policy for action selection
        if np.random.rand() < self.exploration_rate:
            # Explore: select a random action
            return np.random.choice(self.num_actions)
        else:
            # Exploit: select action with highest Q-value for current state
            return np.argmax(self.q_table[state])

    def update_q_table(self, state, action, reward, next_state):
        # Q-value update using Q-learning equation
        best_next_action = np.argmax(self.q_table[next_state])
        td_target = reward + self.discount_factor * self.q_table[next_state, best_next_action]
        td_error = td_target - self.q_table[state, action]
        self.q_table[state, action] += self.learning_rate * td_error

# %%
# Example usage:
# Define environment parameters
num_states = 3
num_actions = 2

# Create Q-learning agent
agent = QLearningAgent(num_states, num_actions)

# Simulate episodes
num_episodes = 1000
for episode in range(num_episodes):
    # Reset environment and initialize state
    state = 0
    done = False
    total_reward = 0
    
    while not done:
        # Select action based on current state
        action = agent.select_action(state)
        
        # Simulate environment (transition to next state and receive reward)
        if state == 0 and action == 1:
            next_state = 1
            reward = 1
        elif state == 1 and action == 0:
            next_state = 0
            reward = 2
        elif state == 1 and action == 1:
            next_state = 2
            reward = 3
        else:
            next_state = state
            reward = 0
        
        # Update Q-table based on observed transition
        agent.update_q_table(state, action, reward, next_state)
        
        # Update current state
        state = next_state
        
        # Accumulate total reward
        total_reward += reward
        
        # Check if episode is done
        if state == num_states - 1:
            done = True
    
    # Print total reward for episode
    print("Episode {}: Total Reward = {}".format(episode + 1, total_reward))
# Out:
# Episode 1: Total Reward = 70
# Episode 2: Total Reward = 79
# Episode 3: Total Reward = 19
# Episode 4: Total Reward = 22
# Episode 5: Total Reward = 124
# Episode 6: Total Reward = 31
# Episode 7: Total Reward = 40
# Episode 8: Total Reward = 265
# Episode 9: Total Reward = 31
# Episode 10: Total Reward = 16
# Episode 11: Total Reward = 118
# Episode 12: Total Reward = 85
# Episode 13: Total Reward = 22
# Episode 14: Total Reward = 31
# Episode 15: Total Reward = 103
# Episode 16: Total Reward = 52
# Episode 17: Total Reward = 49
# Episode 18: Total Reward = 148
# Episode 19: Total Reward = 109
# Episode 20: Total Reward = 7
# Episode 21: Total Reward = 10
# Episode 22: Total Reward = 10
# Episode 23: Total Reward = 127
# Episode 24: Total Reward = 100
# Episode 25: Total Reward = 88
# Episode 26: Total Reward = 31
# Episode 27: Total Reward = 94
# Episode 28: Total Reward = 28
# Episode 29: Total Reward = 55
# Episode 30: Total Reward = 28
# Episode 31: Total Reward = 55
# Episode 32: Total Reward = 64
# Episode 33: Total Reward = 19
# Episode 34: Total Reward = 19
# Episode 35: Total Reward = 88
# Episode 36: Total Reward = 70
# Episode 37: Total Reward = 79
# Episode 38: Total Reward = 154
# Episode 39: Total Reward = 31
# Episode 40: Total Reward = 79
# Episode 41: Total Reward = 7
# Episode 42: Total Reward = 16
# Episode 43: Total Reward = 31
# Episode 44: Total Reward = 10
# Episode 45: Total Reward = 7
# Episode 46: Total Reward = 64
# Episode 47: Total Reward = 142
# Episode 48: Total Reward = 64
# Episode 49: Total Reward = 70
# Episode 50: Total Reward = 37
# Episode 51: Total Reward = 10
# Episode 52: Total Reward = 19
# Episode 53: Total Reward = 58
# Episode 54: Total Reward = 160
# Episode 55: Total Reward = 46
# Episode 56: Total Reward = 34
# Episode 57: Total Reward = 52
# Episode 58: Total Reward = 85
# Episode 59: Total Reward = 100
# Episode 60: Total Reward = 7
# Episode 61: Total Reward = 7
# Episode 62: Total Reward = 55
# Episode 63: Total Reward = 73
# Episode 64: Total Reward = 10
# Episode 65: Total Reward = 79
# Episode 66: Total Reward = 28
# Episode 67: Total Reward = 25
# Episode 68: Total Reward = 22
# Episode 69: Total Reward = 46
# Episode 70: Total Reward = 58
# Episode 71: Total Reward = 58
# Episode 72: Total Reward = 34
# Episode 73: Total Reward = 25
# Episode 74: Total Reward = 58
# Episode 75: Total Reward = 34
# Episode 76: Total Reward = 112
# Episode 77: Total Reward = 151
# Episode 78: Total Reward = 178
# Episode 79: Total Reward = 121
# Episode 80: Total Reward = 31
# Episode 81: Total Reward = 37
# Episode 82: Total Reward = 58
# Episode 83: Total Reward = 55
# Episode 84: Total Reward = 31
# Episode 85: Total Reward = 10
# Episode 86: Total Reward = 46
# Episode 87: Total Reward = 64
# Episode 88: Total Reward = 100
# Episode 89: Total Reward = 73
# Episode 90: Total Reward = 103
# Episode 91: Total Reward = 7
# Episode 92: Total Reward = 19
# Episode 93: Total Reward = 94
# Episode 94: Total Reward = 115
# Episode 95: Total Reward = 58
# Episode 96: Total Reward = 61
# Episode 97: Total Reward = 76
# Episode 98: Total Reward = 73
# Episode 99: Total Reward = 97
# Episode 100: Total Reward = 49
# Episode 101: Total Reward = 22
# Episode 102: Total Reward = 7
# Episode 103: Total Reward = 13
# Episode 104: Total Reward = 61
# Episode 105: Total Reward = 79
# Episode 106: Total Reward = 82
# Episode 107: Total Reward = 91
# Episode 108: Total Reward = 19
# Episode 109: Total Reward = 13
# Episode 110: Total Reward = 19
# Episode 111: Total Reward = 70
# Episode 112: Total Reward = 115
# Episode 113: Total Reward = 151
# Episode 114: Total Reward = 94
# Episode 115: Total Reward = 7
# Episode 116: Total Reward = 13
# Episode 117: Total Reward = 118
# Episode 118: Total Reward = 208
# Episode 119: Total Reward = 4
# Episode 120: Total Reward = 109
# Episode 121: Total Reward = 40
# Episode 122: Total Reward = 16
# Episode 123: Total Reward = 19
# Episode 124: Total Reward = 46
# Episode 125: Total Reward = 112
# Episode 126: Total Reward = 64
# Episode 127: Total Reward = 10
# Episode 128: Total Reward = 28
# Episode 129: Total Reward = 133
# Episode 130: Total Reward = 118
# Episode 131: Total Reward = 70
# Episode 132: Total Reward = 34
# Episode 133: Total Reward = 43
# Episode 134: Total Reward = 16
# Episode 135: Total Reward = 10
# Episode 136: Total Reward = 10
# Episode 137: Total Reward = 4
# Episode 138: Total Reward = 52
# Episode 139: Total Reward = 40
# Episode 140: Total Reward = 31
# Episode 141: Total Reward = 19
# Episode 142: Total Reward = 28
# Episode 143: Total Reward = 34
# Episode 144: Total Reward = 7
# Episode 145: Total Reward = 52
# Episode 146: Total Reward = 16
# Episode 147: Total Reward = 40
# Episode 148: Total Reward = 34
# Episode 149: Total Reward = 70
# Episode 150: Total Reward = 127
# Episode 151: Total Reward = 4
# Episode 152: Total Reward = 76
# Episode 153: Total Reward = 106
# Episode 154: Total Reward = 37
# Episode 155: Total Reward = 34
# Episode 156: Total Reward = 34
# Episode 157: Total Reward = 10
# Episode 158: Total Reward = 7
# Episode 159: Total Reward = 7
# Episode 160: Total Reward = 7
# Episode 161: Total Reward = 25
# Episode 162: Total Reward = 58
# Episode 163: Total Reward = 130
# Episode 164: Total Reward = 79
# Episode 165: Total Reward = 7
# Episode 166: Total Reward = 13
# Episode 167: Total Reward = 70
# Episode 168: Total Reward = 40
# Episode 169: Total Reward = 37
# Episode 170: Total Reward = 64
# Episode 171: Total Reward = 34
# Episode 172: Total Reward = 58
# Episode 173: Total Reward = 64
# Episode 174: Total Reward = 64
# Episode 175: Total Reward = 7
# Episode 176: Total Reward = 37
# Episode 177: Total Reward = 58
# Episode 178: Total Reward = 13
# Episode 179: Total Reward = 58
# Episode 180: Total Reward = 298
# Episode 181: Total Reward = 16
# Episode 182: Total Reward = 13
# Episode 183: Total Reward = 109
# Episode 184: Total Reward = 4
# Episode 185: Total Reward = 76
# Episode 186: Total Reward = 31
# Episode 187: Total Reward = 10
# Episode 188: Total Reward = 88
# Episode 189: Total Reward = 46
# Episode 190: Total Reward = 25
# Episode 191: Total Reward = 13
# Episode 192: Total Reward = 10
# Episode 193: Total Reward = 115
# Episode 194: Total Reward = 55
# Episode 195: Total Reward = 133
# Episode 196: Total Reward = 100
# Episode 197: Total Reward = 10
# Episode 198: Total Reward = 49
# Episode 199: Total Reward = 40
# Episode 200: Total Reward = 199
# Episode 201: Total Reward = 37
# Episode 202: Total Reward = 19
# Episode 203: Total Reward = 52
# Episode 204: Total Reward = 100
# Episode 205: Total Reward = 37
# Episode 206: Total Reward = 25
# Episode 207: Total Reward = 157
# Episode 208: Total Reward = 4
# Episode 209: Total Reward = 28
# Episode 210: Total Reward = 31
# Episode 211: Total Reward = 22
# Episode 212: Total Reward = 46
# Episode 213: Total Reward = 19
# Episode 214: Total Reward = 49
# Episode 215: Total Reward = 13
# Episode 216: Total Reward = 37
# Episode 217: Total Reward = 52
# Episode 218: Total Reward = 88
# Episode 219: Total Reward = 94
# Episode 220: Total Reward = 148
# Episode 221: Total Reward = 10
# Episode 222: Total Reward = 100
# Episode 223: Total Reward = 4
# Episode 224: Total Reward = 88
# Episode 225: Total Reward = 31
# Episode 226: Total Reward = 22
# Episode 227: Total Reward = 43
# Episode 228: Total Reward = 76
# Episode 229: Total Reward = 250
# Episode 230: Total Reward = 10
# Episode 231: Total Reward = 88
# Episode 232: Total Reward = 49
# Episode 233: Total Reward = 37
# Episode 234: Total Reward = 28
# Episode 235: Total Reward = 61
# Episode 236: Total Reward = 28
# Episode 237: Total Reward = 85
# Episode 238: Total Reward = 127
# Episode 239: Total Reward = 88
# Episode 240: Total Reward = 37
# Episode 241: Total Reward = 73
# Episode 242: Total Reward = 49
# Episode 243: Total Reward = 31
# Episode 244: Total Reward = 109
# Episode 245: Total Reward = 13
# Episode 246: Total Reward = 25
# Episode 247: Total Reward = 34
# Episode 248: Total Reward = 4
# Episode 249: Total Reward = 151
# Episode 250: Total Reward = 16
# Episode 251: Total Reward = 58
# Episode 252: Total Reward = 73
# Episode 253: Total Reward = 154
# Episode 254: Total Reward = 16
# Episode 255: Total Reward = 85
# Episode 256: Total Reward = 13
# Episode 257: Total Reward = 7
# Episode 258: Total Reward = 340
# Episode 259: Total Reward = 19
# Episode 260: Total Reward = 55
# Episode 261: Total Reward = 184
# Episode 262: Total Reward = 139
# Episode 263: Total Reward = 97
# Episode 264: Total Reward = 61
# Episode 265: Total Reward = 91
# Episode 266: Total Reward = 7
# Episode 267: Total Reward = 58
# Episode 268: Total Reward = 76
# Episode 269: Total Reward = 22
# Episode 270: Total Reward = 49
# Episode 271: Total Reward = 226
# Episode 272: Total Reward = 136
# Episode 273: Total Reward = 16
# Episode 274: Total Reward = 106
# Episode 275: Total Reward = 28
# Episode 276: Total Reward = 10
# Episode 277: Total Reward = 10
# Episode 278: Total Reward = 52
# Episode 279: Total Reward = 7
# Episode 280: Total Reward = 13
# Episode 281: Total Reward = 211
# Episode 282: Total Reward = 46
# Episode 283: Total Reward = 169
# Episode 284: Total Reward = 52
# Episode 285: Total Reward = 49
# Episode 286: Total Reward = 31
# Episode 287: Total Reward = 67
# Episode 288: Total Reward = 55
# Episode 289: Total Reward = 16
# Episode 290: Total Reward = 37
# Episode 291: Total Reward = 43
# Episode 292: Total Reward = 133
# Episode 293: Total Reward = 172
# Episode 294: Total Reward = 4
# Episode 295: Total Reward = 43
# Episode 296: Total Reward = 7
# Episode 297: Total Reward = 232
# Episode 298: Total Reward = 70
# Episode 299: Total Reward = 16
# Episode 300: Total Reward = 34
# Episode 301: Total Reward = 55
# Episode 302: Total Reward = 64
# Episode 303: Total Reward = 31
# Episode 304: Total Reward = 61
# Episode 305: Total Reward = 94
# Episode 306: Total Reward = 31
# Episode 307: Total Reward = 22
# Episode 308: Total Reward = 148
# Episode 309: Total Reward = 31
# Episode 310: Total Reward = 19
# Episode 311: Total Reward = 139
# Episode 312: Total Reward = 49
# Episode 313: Total Reward = 46
# Episode 314: Total Reward = 160
# Episode 315: Total Reward = 46
# Episode 316: Total Reward = 190
# Episode 317: Total Reward = 34
# Episode 318: Total Reward = 88
# Episode 319: Total Reward = 19
# Episode 320: Total Reward = 151
# Episode 321: Total Reward = 67
# Episode 322: Total Reward = 55
# Episode 323: Total Reward = 25
# Episode 324: Total Reward = 55
# Episode 325: Total Reward = 190
# Episode 326: Total Reward = 148
# Episode 327: Total Reward = 166
# Episode 328: Total Reward = 16
# Episode 329: Total Reward = 55
# Episode 330: Total Reward = 112
# Episode 331: Total Reward = 49
# Episode 332: Total Reward = 61
# Episode 333: Total Reward = 55
# Episode 334: Total Reward = 22
# Episode 335: Total Reward = 73
# Episode 336: Total Reward = 130
# Episode 337: Total Reward = 25
# Episode 338: Total Reward = 136
# Episode 339: Total Reward = 16
# Episode 340: Total Reward = 49
# Episode 341: Total Reward = 31
# Episode 342: Total Reward = 100
# Episode 343: Total Reward = 7
# Episode 344: Total Reward = 43
# Episode 345: Total Reward = 16
# Episode 346: Total Reward = 4
# Episode 347: Total Reward = 124
# Episode 348: Total Reward = 67
# Episode 349: Total Reward = 49
# Episode 350: Total Reward = 40
# Episode 351: Total Reward = 7
# Episode 352: Total Reward = 4
# Episode 353: Total Reward = 55
# Episode 354: Total Reward = 76
# Episode 355: Total Reward = 31
# Episode 356: Total Reward = 22
# Episode 357: Total Reward = 61
# Episode 358: Total Reward = 49
# Episode 359: Total Reward = 40
# Episode 360: Total Reward = 16
# Episode 361: Total Reward = 4
# Episode 362: Total Reward = 28
# Episode 363: Total Reward = 46
# Episode 364: Total Reward = 115
# Episode 365: Total Reward = 31
# Episode 366: Total Reward = 7
# Episode 367: Total Reward = 10
# Episode 368: Total Reward = 7
# Episode 369: Total Reward = 43
# Episode 370: Total Reward = 67
# Episode 371: Total Reward = 139
# Episode 372: Total Reward = 28
# Episode 373: Total Reward = 64
# Episode 374: Total Reward = 34
# Episode 375: Total Reward = 28
# Episode 376: Total Reward = 91
# Episode 377: Total Reward = 31
# Episode 378: Total Reward = 10
# Episode 379: Total Reward = 13
# Episode 380: Total Reward = 49
# Episode 381: Total Reward = 64
# Episode 382: Total Reward = 25
# Episode 383: Total Reward = 55
# Episode 384: Total Reward = 37
# Episode 385: Total Reward = 100
# Episode 386: Total Reward = 40
# Episode 387: Total Reward = 4
# Episode 388: Total Reward = 130
# Episode 389: Total Reward = 52
# Episode 390: Total Reward = 37
# Episode 391: Total Reward = 13
# Episode 392: Total Reward = 100
# Episode 393: Total Reward = 25
# Episode 394: Total Reward = 7
# Episode 395: Total Reward = 52
# Episode 396: Total Reward = 31
# Episode 397: Total Reward = 13
# Episode 398: Total Reward = 34
# Episode 399: Total Reward = 31
# Episode 400: Total Reward = 82
# Episode 401: Total Reward = 94
# Episode 402: Total Reward = 55
# Episode 403: Total Reward = 10
# Episode 404: Total Reward = 10
# Episode 405: Total Reward = 13
# Episode 406: Total Reward = 217
# Episode 407: Total Reward = 43
# Episode 408: Total Reward = 52
# Episode 409: Total Reward = 115
# Episode 410: Total Reward = 61
# Episode 411: Total Reward = 127
# Episode 412: Total Reward = 13
# Episode 413: Total Reward = 4
# Episode 414: Total Reward = 55
# Episode 415: Total Reward = 112
# Episode 416: Total Reward = 73
# Episode 417: Total Reward = 10
# Episode 418: Total Reward = 334
# Episode 419: Total Reward = 10
# Episode 420: Total Reward = 25
# Episode 421: Total Reward = 13
# Episode 422: Total Reward = 19
# Episode 423: Total Reward = 40
# Episode 424: Total Reward = 37
# Episode 425: Total Reward = 4
# Episode 426: Total Reward = 7
# Episode 427: Total Reward = 16
# Episode 428: Total Reward = 61
# Episode 429: Total Reward = 160
# Episode 430: Total Reward = 37
# Episode 431: Total Reward = 10
# Episode 432: Total Reward = 34
# Episode 433: Total Reward = 184
# Episode 434: Total Reward = 91
# Episode 435: Total Reward = 10
# Episode 436: Total Reward = 31
# Episode 437: Total Reward = 43
# Episode 438: Total Reward = 61
# Episode 439: Total Reward = 16
# Episode 440: Total Reward = 46
# Episode 441: Total Reward = 7
# Episode 442: Total Reward = 109
# Episode 443: Total Reward = 7
# Episode 444: Total Reward = 16
# Episode 445: Total Reward = 28
# Episode 446: Total Reward = 40
# Episode 447: Total Reward = 22
# Episode 448: Total Reward = 55
# Episode 449: Total Reward = 31
# Episode 450: Total Reward = 151
# Episode 451: Total Reward = 4
# Episode 452: Total Reward = 43
# Episode 453: Total Reward = 88
# Episode 454: Total Reward = 40
# Episode 455: Total Reward = 274
# Episode 456: Total Reward = 4
# Episode 457: Total Reward = 76
# Episode 458: Total Reward = 55
# Episode 459: Total Reward = 76
# Episode 460: Total Reward = 40
# Episode 461: Total Reward = 226
# Episode 462: Total Reward = 4
# Episode 463: Total Reward = 19
# Episode 464: Total Reward = 46
# Episode 465: Total Reward = 31
# Episode 466: Total Reward = 7
# Episode 467: Total Reward = 31
# Episode 468: Total Reward = 43
# Episode 469: Total Reward = 133
# Episode 470: Total Reward = 79
# Episode 471: Total Reward = 13
# Episode 472: Total Reward = 43
# Episode 473: Total Reward = 40
# Episode 474: Total Reward = 40
# Episode 475: Total Reward = 49
# Episode 476: Total Reward = 4
# Episode 477: Total Reward = 76
# Episode 478: Total Reward = 28
# Episode 479: Total Reward = 49
# Episode 480: Total Reward = 4
# Episode 481: Total Reward = 43
# Episode 482: Total Reward = 34
# Episode 483: Total Reward = 70
# Episode 484: Total Reward = 22
# Episode 485: Total Reward = 28
# Episode 486: Total Reward = 97
# Episode 487: Total Reward = 4
# Episode 488: Total Reward = 100
# Episode 489: Total Reward = 28
# Episode 490: Total Reward = 61
# Episode 491: Total Reward = 73
# Episode 492: Total Reward = 274
# Episode 493: Total Reward = 184
# Episode 494: Total Reward = 145
# Episode 495: Total Reward = 16
# Episode 496: Total Reward = 85
# Episode 497: Total Reward = 73
# Episode 498: Total Reward = 55
# Episode 499: Total Reward = 100
# Episode 500: Total Reward = 7
# Episode 501: Total Reward = 94
# Episode 502: Total Reward = 130
# Episode 503: Total Reward = 16
# Episode 504: Total Reward = 109
# Episode 505: Total Reward = 103
# Episode 506: Total Reward = 55
# Episode 507: Total Reward = 52
# Episode 508: Total Reward = 67
# Episode 509: Total Reward = 22
# Episode 510: Total Reward = 91
# Episode 511: Total Reward = 61
# Episode 512: Total Reward = 55
# Episode 513: Total Reward = 127
# Episode 514: Total Reward = 25
# Episode 515: Total Reward = 97
# Episode 516: Total Reward = 25
# Episode 517: Total Reward = 49
# Episode 518: Total Reward = 40
# Episode 519: Total Reward = 58
# Episode 520: Total Reward = 154
# Episode 521: Total Reward = 22
# Episode 522: Total Reward = 10
# Episode 523: Total Reward = 13
# Episode 524: Total Reward = 34
# Episode 525: Total Reward = 46
# Episode 526: Total Reward = 34
# Episode 527: Total Reward = 4
# Episode 528: Total Reward = 151
# Episode 529: Total Reward = 52
# Episode 530: Total Reward = 25
# Episode 531: Total Reward = 28
# Episode 532: Total Reward = 19
# Episode 533: Total Reward = 52
# Episode 534: Total Reward = 58
# Episode 535: Total Reward = 34
# Episode 536: Total Reward = 208
# Episode 537: Total Reward = 37
# Episode 538: Total Reward = 7
# Episode 539: Total Reward = 28
# Episode 540: Total Reward = 43
# Episode 541: Total Reward = 16
# Episode 542: Total Reward = 82
# Episode 543: Total Reward = 79
# Episode 544: Total Reward = 7
# Episode 545: Total Reward = 76
# Episode 546: Total Reward = 46
# Episode 547: Total Reward = 13
# Episode 548: Total Reward = 13
# Episode 549: Total Reward = 103
# Episode 550: Total Reward = 7
# Episode 551: Total Reward = 64
# Episode 552: Total Reward = 4
# Episode 553: Total Reward = 25
# Episode 554: Total Reward = 31
# Episode 555: Total Reward = 4
# Episode 556: Total Reward = 19
# Episode 557: Total Reward = 43
# Episode 558: Total Reward = 142
# Episode 559: Total Reward = 16
# Episode 560: Total Reward = 40
# Episode 561: Total Reward = 76
# Episode 562: Total Reward = 58
# Episode 563: Total Reward = 4
# Episode 564: Total Reward = 79
# Episode 565: Total Reward = 43
# Episode 566: Total Reward = 19
# Episode 567: Total Reward = 82
# Episode 568: Total Reward = 100
# Episode 569: Total Reward = 7
# Episode 570: Total Reward = 64
# Episode 571: Total Reward = 40
# Episode 572: Total Reward = 109
# Episode 573: Total Reward = 7
# Episode 574: Total Reward = 10
# Episode 575: Total Reward = 103
# Episode 576: Total Reward = 37
# Episode 577: Total Reward = 25
# Episode 578: Total Reward = 76
# Episode 579: Total Reward = 82
# Episode 580: Total Reward = 124
# Episode 581: Total Reward = 79
# Episode 582: Total Reward = 82
# Episode 583: Total Reward = 139
# Episode 584: Total Reward = 106
# Episode 585: Total Reward = 238
# Episode 586: Total Reward = 307
# Episode 587: Total Reward = 130
# Episode 588: Total Reward = 10
# Episode 589: Total Reward = 10
# Episode 590: Total Reward = 73
# Episode 591: Total Reward = 58
# Episode 592: Total Reward = 4
# Episode 593: Total Reward = 16
# Episode 594: Total Reward = 10
# Episode 595: Total Reward = 7
# Episode 596: Total Reward = 7
# Episode 597: Total Reward = 7
# Episode 598: Total Reward = 85
# Episode 599: Total Reward = 25
# Episode 600: Total Reward = 4
# Episode 601: Total Reward = 91
# Episode 602: Total Reward = 10
# Episode 603: Total Reward = 73
# Episode 604: Total Reward = 25
# Episode 605: Total Reward = 31
# Episode 606: Total Reward = 22
# Episode 607: Total Reward = 70
# Episode 608: Total Reward = 328
# Episode 609: Total Reward = 22
# Episode 610: Total Reward = 7
# Episode 611: Total Reward = 178
# Episode 612: Total Reward = 34
# Episode 613: Total Reward = 34
# Episode 614: Total Reward = 106
# Episode 615: Total Reward = 19
# Episode 616: Total Reward = 232
# Episode 617: Total Reward = 19
# Episode 618: Total Reward = 100
# Episode 619: Total Reward = 40
# Episode 620: Total Reward = 88
# Episode 621: Total Reward = 16
# Episode 622: Total Reward = 16
# Episode 623: Total Reward = 10
# Episode 624: Total Reward = 25
# Episode 625: Total Reward = 76
# Episode 626: Total Reward = 67
# Episode 627: Total Reward = 49
# Episode 628: Total Reward = 46
# Episode 629: Total Reward = 19
# Episode 630: Total Reward = 73
# Episode 631: Total Reward = 13
# Episode 632: Total Reward = 31
# Episode 633: Total Reward = 7
# Episode 634: Total Reward = 82
# Episode 635: Total Reward = 13
# Episode 636: Total Reward = 34
# Episode 637: Total Reward = 37
# Episode 638: Total Reward = 4
# Episode 639: Total Reward = 229
# Episode 640: Total Reward = 4
# Episode 641: Total Reward = 91
# Episode 642: Total Reward = 10
# Episode 643: Total Reward = 301
# Episode 644: Total Reward = 16
# Episode 645: Total Reward = 22
# Episode 646: Total Reward = 130
# Episode 647: Total Reward = 25
# Episode 648: Total Reward = 10
# Episode 649: Total Reward = 28
# Episode 650: Total Reward = 85
# Episode 651: Total Reward = 19
# Episode 652: Total Reward = 64
# Episode 653: Total Reward = 40
# Episode 654: Total Reward = 151
# Episode 655: Total Reward = 55
# Episode 656: Total Reward = 46
# Episode 657: Total Reward = 25
# Episode 658: Total Reward = 31
# Episode 659: Total Reward = 16
# Episode 660: Total Reward = 7
# Episode 661: Total Reward = 19
# Episode 662: Total Reward = 4
# Episode 663: Total Reward = 10
# Episode 664: Total Reward = 142
# Episode 665: Total Reward = 19
# Episode 666: Total Reward = 34
# Episode 667: Total Reward = 58
# Episode 668: Total Reward = 73
# Episode 669: Total Reward = 67
# Episode 670: Total Reward = 7
# Episode 671: Total Reward = 91
# Episode 672: Total Reward = 4
# Episode 673: Total Reward = 52
# Episode 674: Total Reward = 16
# Episode 675: Total Reward = 28
# Episode 676: Total Reward = 43
# Episode 677: Total Reward = 97
# Episode 678: Total Reward = 178
# Episode 679: Total Reward = 106
# Episode 680: Total Reward = 58
# Episode 681: Total Reward = 97
# Episode 682: Total Reward = 19
# Episode 683: Total Reward = 13
# Episode 684: Total Reward = 64
# Episode 685: Total Reward = 19
# Episode 686: Total Reward = 76
# Episode 687: Total Reward = 19
# Episode 688: Total Reward = 37
# Episode 689: Total Reward = 16
# Episode 690: Total Reward = 4
# Episode 691: Total Reward = 25
# Episode 692: Total Reward = 76
# Episode 693: Total Reward = 52
# Episode 694: Total Reward = 67
# Episode 695: Total Reward = 13
# Episode 696: Total Reward = 247
# Episode 697: Total Reward = 16
# Episode 698: Total Reward = 31
# Episode 699: Total Reward = 58
# Episode 700: Total Reward = 22
# Episode 701: Total Reward = 28
# Episode 702: Total Reward = 166
# Episode 703: Total Reward = 121
# Episode 704: Total Reward = 49
# Episode 705: Total Reward = 37
# Episode 706: Total Reward = 10
# Episode 707: Total Reward = 133
# Episode 708: Total Reward = 70
# Episode 709: Total Reward = 139
# Episode 710: Total Reward = 7
# Episode 711: Total Reward = 7
# Episode 712: Total Reward = 52
# Episode 713: Total Reward = 55
# Episode 714: Total Reward = 34
# Episode 715: Total Reward = 28
# Episode 716: Total Reward = 115
# Episode 717: Total Reward = 16
# Episode 718: Total Reward = 100
# Episode 719: Total Reward = 13
# Episode 720: Total Reward = 91
# Episode 721: Total Reward = 4
# Episode 722: Total Reward = 16
# Episode 723: Total Reward = 10
# Episode 724: Total Reward = 40
# Episode 725: Total Reward = 46
# Episode 726: Total Reward = 145
# Episode 727: Total Reward = 274
# Episode 728: Total Reward = 4
# Episode 729: Total Reward = 85
# Episode 730: Total Reward = 13
# Episode 731: Total Reward = 13
# Episode 732: Total Reward = 4
# Episode 733: Total Reward = 64
# Episode 734: Total Reward = 64
# Episode 735: Total Reward = 10
# Episode 736: Total Reward = 55
# Episode 737: Total Reward = 40
# Episode 738: Total Reward = 160
# Episode 739: Total Reward = 28
# Episode 740: Total Reward = 49
# Episode 741: Total Reward = 10
# Episode 742: Total Reward = 22
# Episode 743: Total Reward = 22
# Episode 744: Total Reward = 10
# Episode 745: Total Reward = 40
# Episode 746: Total Reward = 25
# Episode 747: Total Reward = 55
# Episode 748: Total Reward = 82
# Episode 749: Total Reward = 43
# Episode 750: Total Reward = 22
# Episode 751: Total Reward = 10
# Episode 752: Total Reward = 13
# Episode 753: Total Reward = 34
# Episode 754: Total Reward = 28
# Episode 755: Total Reward = 166
# Episode 756: Total Reward = 22
# Episode 757: Total Reward = 85
# Episode 758: Total Reward = 43
# Episode 759: Total Reward = 4
# Episode 760: Total Reward = 100
# Episode 761: Total Reward = 22
# Episode 762: Total Reward = 46
# Episode 763: Total Reward = 34
# Episode 764: Total Reward = 73
# Episode 765: Total Reward = 13
# Episode 766: Total Reward = 28
# Episode 767: Total Reward = 7
# Episode 768: Total Reward = 19
# Episode 769: Total Reward = 7
# Episode 770: Total Reward = 19
# Episode 771: Total Reward = 4
# Episode 772: Total Reward = 28
# Episode 773: Total Reward = 40
# Episode 774: Total Reward = 7
# Episode 775: Total Reward = 190
# Episode 776: Total Reward = 106
# Episode 777: Total Reward = 4
# Episode 778: Total Reward = 73
# Episode 779: Total Reward = 34
# Episode 780: Total Reward = 13
# Episode 781: Total Reward = 37
# Episode 782: Total Reward = 61
# Episode 783: Total Reward = 61
# Episode 784: Total Reward = 22
# Episode 785: Total Reward = 64
# Episode 786: Total Reward = 22
# Episode 787: Total Reward = 58
# Episode 788: Total Reward = 67
# Episode 789: Total Reward = 88
# Episode 790: Total Reward = 46
# Episode 791: Total Reward = 25
# Episode 792: Total Reward = 103
# Episode 793: Total Reward = 16
# Episode 794: Total Reward = 22
# Episode 795: Total Reward = 64
# Episode 796: Total Reward = 7
# Episode 797: Total Reward = 19
# Episode 798: Total Reward = 178
# Episode 799: Total Reward = 64
# Episode 800: Total Reward = 10
# Episode 801: Total Reward = 31
# Episode 802: Total Reward = 28
# Episode 803: Total Reward = 184
# Episode 804: Total Reward = 4
# Episode 805: Total Reward = 49
# Episode 806: Total Reward = 31
# Episode 807: Total Reward = 28
# Episode 808: Total Reward = 28
# Episode 809: Total Reward = 115
# Episode 810: Total Reward = 34
# Episode 811: Total Reward = 124
# Episode 812: Total Reward = 67
# Episode 813: Total Reward = 13
# Episode 814: Total Reward = 94
# Episode 815: Total Reward = 13
# Episode 816: Total Reward = 70
# Episode 817: Total Reward = 94
# Episode 818: Total Reward = 16
# Episode 819: Total Reward = 25
# Episode 820: Total Reward = 55
# Episode 821: Total Reward = 64
# Episode 822: Total Reward = 34
# Episode 823: Total Reward = 19
# Episode 824: Total Reward = 22
# Episode 825: Total Reward = 55
# Episode 826: Total Reward = 31
# Episode 827: Total Reward = 31
# Episode 828: Total Reward = 7
# Episode 829: Total Reward = 154
# Episode 830: Total Reward = 22
# Episode 831: Total Reward = 127
# Episode 832: Total Reward = 22
# Episode 833: Total Reward = 187
# Episode 834: Total Reward = 139
# Episode 835: Total Reward = 25
# Episode 836: Total Reward = 73
# Episode 837: Total Reward = 19
# Episode 838: Total Reward = 82
# Episode 839: Total Reward = 85
# Episode 840: Total Reward = 139
# Episode 841: Total Reward = 169
# Episode 842: Total Reward = 40
# Episode 843: Total Reward = 31
# Episode 844: Total Reward = 88
# Episode 845: Total Reward = 52
# Episode 846: Total Reward = 28
# Episode 847: Total Reward = 7
# Episode 848: Total Reward = 22
# Episode 849: Total Reward = 28
# Episode 850: Total Reward = 40
# Episode 851: Total Reward = 31
# Episode 852: Total Reward = 37
# Episode 853: Total Reward = 157
# Episode 854: Total Reward = 79
# Episode 855: Total Reward = 28
# Episode 856: Total Reward = 13
# Episode 857: Total Reward = 13
# Episode 858: Total Reward = 13
# Episode 859: Total Reward = 10
# Episode 860: Total Reward = 76
# Episode 861: Total Reward = 10
# Episode 862: Total Reward = 34
# Episode 863: Total Reward = 79
# Episode 864: Total Reward = 22
# Episode 865: Total Reward = 49
# Episode 866: Total Reward = 16
# Episode 867: Total Reward = 55
# Episode 868: Total Reward = 58
# Episode 869: Total Reward = 10
# Episode 870: Total Reward = 157
# Episode 871: Total Reward = 82
# Episode 872: Total Reward = 76
# Episode 873: Total Reward = 37
# Episode 874: Total Reward = 265
# Episode 875: Total Reward = 52
# Episode 876: Total Reward = 88
# Episode 877: Total Reward = 16
# Episode 878: Total Reward = 4
# Episode 879: Total Reward = 31
# Episode 880: Total Reward = 19
# Episode 881: Total Reward = 19
# Episode 882: Total Reward = 97
# Episode 883: Total Reward = 256
# Episode 884: Total Reward = 70
# Episode 885: Total Reward = 4
# Episode 886: Total Reward = 16
# Episode 887: Total Reward = 55
# Episode 888: Total Reward = 22
# Episode 889: Total Reward = 19
# Episode 890: Total Reward = 4
# Episode 891: Total Reward = 67
# Episode 892: Total Reward = 37
# Episode 893: Total Reward = 64
# Episode 894: Total Reward = 157
# Episode 895: Total Reward = 115
# Episode 896: Total Reward = 34
# Episode 897: Total Reward = 64
# Episode 898: Total Reward = 7
# Episode 899: Total Reward = 7
# Episode 900: Total Reward = 34
# Episode 901: Total Reward = 46
# Episode 902: Total Reward = 25
# Episode 903: Total Reward = 244
# Episode 904: Total Reward = 82
# Episode 905: Total Reward = 49
# Episode 906: Total Reward = 10
# Episode 907: Total Reward = 10
# Episode 908: Total Reward = 22
# Episode 909: Total Reward = 55
# Episode 910: Total Reward = 115
# Episode 911: Total Reward = 13
# Episode 912: Total Reward = 40
# Episode 913: Total Reward = 55
# Episode 914: Total Reward = 4
# Episode 915: Total Reward = 259
# Episode 916: Total Reward = 49
# Episode 917: Total Reward = 196
# Episode 918: Total Reward = 25
# Episode 919: Total Reward = 148
# Episode 920: Total Reward = 7
# Episode 921: Total Reward = 145
# Episode 922: Total Reward = 67
# Episode 923: Total Reward = 40
# Episode 924: Total Reward = 124
# Episode 925: Total Reward = 16
# Episode 926: Total Reward = 118
# Episode 927: Total Reward = 4
# Episode 928: Total Reward = 25
# Episode 929: Total Reward = 244
# Episode 930: Total Reward = 52
# Episode 931: Total Reward = 4
# Episode 932: Total Reward = 13
# Episode 933: Total Reward = 4
# Episode 934: Total Reward = 151
# Episode 935: Total Reward = 70
# Episode 936: Total Reward = 13
# Episode 937: Total Reward = 4
# Episode 938: Total Reward = 13
# Episode 939: Total Reward = 67
# Episode 940: Total Reward = 10
# Episode 941: Total Reward = 100
# Episode 942: Total Reward = 169
# Episode 943: Total Reward = 25
# Episode 944: Total Reward = 13
# Episode 945: Total Reward = 196
# Episode 946: Total Reward = 157
# Episode 947: Total Reward = 16
# Episode 948: Total Reward = 22
# Episode 949: Total Reward = 40
# Episode 950: Total Reward = 94
# Episode 951: Total Reward = 22
# Episode 952: Total Reward = 151
# Episode 953: Total Reward = 52
# Episode 954: Total Reward = 61
# Episode 955: Total Reward = 28
# Episode 956: Total Reward = 43
# Episode 957: Total Reward = 13
# Episode 958: Total Reward = 49
# Episode 959: Total Reward = 97
# Episode 960: Total Reward = 40
# Episode 961: Total Reward = 28
# Episode 962: Total Reward = 64
# Episode 963: Total Reward = 19
# Episode 964: Total Reward = 115
# Episode 965: Total Reward = 91
# Episode 966: Total Reward = 211
# Episode 967: Total Reward = 130
# Episode 968: Total Reward = 61
# Episode 969: Total Reward = 34
# Episode 970: Total Reward = 46
# Episode 971: Total Reward = 13
# Episode 972: Total Reward = 28
# Episode 973: Total Reward = 82
# Episode 974: Total Reward = 37
# Episode 975: Total Reward = 79
# Episode 976: Total Reward = 10
# Episode 977: Total Reward = 124
# Episode 978: Total Reward = 19
# Episode 979: Total Reward = 106
# Episode 980: Total Reward = 13
# Episode 981: Total Reward = 19
# Episode 982: Total Reward = 28
# Episode 983: Total Reward = 7
# Episode 984: Total Reward = 7
# Episode 985: Total Reward = 4
# Episode 986: Total Reward = 16
# Episode 987: Total Reward = 13
# Episode 988: Total Reward = 58
# Episode 989: Total Reward = 22
# Episode 990: Total Reward = 7
# Episode 991: Total Reward = 7
# Episode 992: Total Reward = 22
# Episode 993: Total Reward = 106
# Episode 994: Total Reward = 16
# Episode 995: Total Reward = 64
# Episode 996: Total Reward = 22
# Episode 997: Total Reward = 4
# Episode 998: Total Reward = 46
# Episode 999: Total Reward = 10
# Episode 1000: Total Reward = 49

# %%
import numpy as np

class QLearningAgent_mine:
    def __init__(self, data, states, actions, alpha=0.1, gamma=0.9, epsilon=0.1):
        self.data = data
        
        self.states = states
        self.actions = actions
        self.pseudo_actions = []
        
        self.num_states = len(states)
        self.num_actions = len(actions)
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.Q = np.zeros((self.num_states, self.num_actions))

    def choose_action(self, state):
        if np.random.uniform(0, 1) < self.epsilon:
            return np.random.choice(self.actions)
        else:
            return self.actions[np.argmax(self.Q[self.states.index(state)])]

    def update_q_table(self, state, action, reward, next_state):
        self.Q[self.states.index(state), self.actions.index(action)] += self.alpha * (
                reward + self.gamma * np.max(self.Q[self.states.index(next_state)]) -
                self.Q[self.states.index(state), self.actions.index(action)])

    def train(self, num_episodes):
        for episode in range(num_episodes):
            #state = np.random.choice(self.states)
            state = self.states[2] # begin 'neutral'
            i = 0
            total_reward = 0

            while True:
                action = self.choose_action(state) # strategy applied
                price_open = self.data['close'].iloc[i] # position open price

                for j in range(i, len(self.data['close'])):
                    price_close = self.data['close'].iloc[j]
                    # Simulate environment and get reward and next state
                    # Update state based on your financial data
                    reward = self.get_reward(state, action, price_open, price_close)  # Define your reward function
                    if reward > 0:
                        next_state = self.states[0]
                    elif reward < 0:
                        next_state = self.states[1]
                    else:
                        next_state = self.states[2]
                    self.update_q_table(state, action, reward, next_state)
                    state = next_state
                i += 1

                total_reward += reward
                
                # Check for terminal state
                if i == len(self.data['close'])-1:
                    break

            print("Episode {}: Total Reward = {}".format(episode + 1, total_reward))

    def get_reward(self, state, action, price_open, price_close):

        if action == 'buy' and price_close > price_open:
            return 1
        elif action == 'buy' and price_close < price_open:
            return -1
        elif action == 'sell' and price_open > price_close:
            return 1
        elif action == 'sell' and price_open < price_close:
            return -1
        else:
            return 0

# %%
import pandas as pd

data = pd.read_csv('data_sample.csv')
data = data.iloc[:100]

# %%
# Example usage
states = ['long', 'short', 'await']
actions = ['buy', 'sell', 'hold']
agent = QLearningAgent_mine(data, states, actions)
agent.train(num_episodes=100)
# Out:
# Episode 1: Total Reward = 34
# Episode 2: Total Reward = 53
# Episode 3: Total Reward = 25
# Episode 4: Total Reward = 43
# Episode 5: Total Reward = 10
# Episode 6: Total Reward = 21
# Episode 7: Total Reward = 39
# Episode 8: Total Reward = 28
# Episode 9: Total Reward = 40
# Episode 10: Total Reward = -12
# Episode 11: Total Reward = -4
# Episode 12: Total Reward = 41
# Episode 13: Total Reward = 49
# Episode 14: Total Reward = 18
# Episode 15: Total Reward = 32
# Episode 16: Total Reward = 31
# Episode 17: Total Reward = 41
# Episode 18: Total Reward = 24
# Episode 19: Total Reward = 22
# Episode 20: Total Reward = 34
# Episode 21: Total Reward = 25
# Episode 22: Total Reward = 19
# Episode 23: Total Reward = 24
# Episode 24: Total Reward = -13
# Episode 25: Total Reward = 34
# Episode 26: Total Reward = -9
# Episode 27: Total Reward = 22
# Episode 28: Total Reward = 23
# Episode 29: Total Reward = 23
# Episode 30: Total Reward = 35
# Episode 31: Total Reward = -5
# Episode 32: Total Reward = 34
# Episode 33: Total Reward = 20
# Episode 34: Total Reward = 11
# Episode 35: Total Reward = 1
# Episode 36: Total Reward = 10
# Episode 37: Total Reward = -6
# Episode 38: Total Reward = 32
# Episode 39: Total Reward = 19
# Episode 40: Total Reward = 27
# Episode 41: Total Reward = 35
# Episode 42: Total Reward = 24
# Episode 43: Total Reward = 42
# Episode 44: Total Reward = 16
# Episode 45: Total Reward = 23
# Episode 46: Total Reward = 41
# Episode 47: Total Reward = 7
# Episode 48: Total Reward = 22
# Episode 49: Total Reward = 37
# Episode 50: Total Reward = 11
# Episode 51: Total Reward = 47
# Episode 52: Total Reward = 21
# Episode 53: Total Reward = 58
# Episode 54: Total Reward = 48
# Episode 55: Total Reward = -6
# Episode 56: Total Reward = 0
# Episode 57: Total Reward = 31
# Episode 58: Total Reward = 0
# Episode 59: Total Reward = -7
# Episode 60: Total Reward = 25
# Episode 61: Total Reward = 46
# Episode 62: Total Reward = 0
# Episode 63: Total Reward = -13
# Episode 64: Total Reward = 14
# Episode 65: Total Reward = 49
# Episode 66: Total Reward = 34
# Episode 67: Total Reward = 50
# Episode 68: Total Reward = 14
# Episode 69: Total Reward = 41
# Episode 70: Total Reward = 6
# Episode 71: Total Reward = -8
# Episode 72: Total Reward = 46
# Episode 73: Total Reward = -7
# Episode 74: Total Reward = 24
# Episode 75: Total Reward = 16
# Episode 76: Total Reward = 42
# Episode 77: Total Reward = 38
# Episode 78: Total Reward = 13
# Episode 79: Total Reward = 40
# Episode 80: Total Reward = 23
# Episode 81: Total Reward = 16
# Episode 82: Total Reward = 28
# Episode 83: Total Reward = 38
# Episode 84: Total Reward = 25
# Episode 85: Total Reward = 7
# Episode 86: Total Reward = 14
# Episode 87: Total Reward = -20
# Episode 88: Total Reward = 26
# Episode 89: Total Reward = 35
# Episode 90: Total Reward = 2
# Episode 91: Total Reward = 43
# Episode 92: Total Reward = 24
# Episode 93: Total Reward = 16
# Episode 94: Total Reward = 32
# Episode 95: Total Reward = 19
# Episode 96: Total Reward = 7
# Episode 97: Total Reward = 55
# Episode 98: Total Reward = 29
# Episode 99: Total Reward = 29
# Episode 100: Total Reward = 27

# %%
agent.Q
# Out:
# array([[6.03899801, 6.3616363 , 5.35597354],
#        [4.30093833, 4.78168404, 5.35599407],
#        [4.96314273, 6.15857983, 5.72002849]])

# %%
agent.Q[states.index('neutral')]
# Out:
# array([4.99888917, 5.19097445, 4.58921745])

# %%
np.argmax(agent.Q[states.index('neutral')])
# Out:
# 1

# %%
import pickle

# Specify the file path where you want to save the pickled Q-matrix
file_path = 'q_matrix.pkl'

# Pickle the Q-matrix and save it to a file
with open(file_path, 'wb') as f:
    pickle.dump(agent.Q, f)

# %%
1706504400 - 1706522460
# Out:
# -18060
