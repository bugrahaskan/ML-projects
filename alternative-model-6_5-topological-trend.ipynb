# %%
import pandas as pd

data = pd.read_csv('data/^NDX_raw_data.csv')
data.rename(columns={'Date': 'date', 'Open':'open', 'High':'high', 'Low':'low', 'Close':'close', 'Volume':'volume'}, inplace=True)

data_backup = data.iloc[3524:]

data = data.iloc[:3524]
data_copy = data.copy()

print('Data imported and copied.', flush=True)
# Out:
# Data imported and copied.

# %%
import numpy as np

## Creating sequences
def create_dataset(dataset, time_step=1, output_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-output_step):
        a = dataset[i:(i+time_step), 0]
        b = dataset[(i+time_step):(i+time_step)+output_step, 0]
        dataX.append(a)
        dataY.append(b)

    return np.array(dataX), np.array(dataY)

period = 60
trend_period = 14
rsi_period = 14
num_features = 1
input_period = 60
output_step = 7
units = 512

# %%
X, y = create_dataset(data[['close']].to_numpy(), time_step=period, output_step=output_step)

data_input = np.array([np.concatenate((X[i], y[i]), axis=0) for i in range(X.shape[0])])

# %%
from scipy.signal import savgol_filter

# Apply Savitzky-Golay filter
window_length = 17  # Window length (must be odd)
polyorder = 1      # Polynomial order

data_savgol = savgol_filter(data_input, window_length, polyorder)

# %%
savgol_cropped = list()

# NO NEED TO CROP
for _savgol in data_savgol:
    savgol_cropped.append(_savgol)

savgol_cropped = np.array(savgol_cropped)

from sklearn.preprocessing import MinMaxScaler

scaler_savgol = list(MinMaxScaler() for i in range(savgol_cropped.shape[0]))
savgol_scaled = list()

for i in range(savgol_cropped.shape[0]):
    savgol_scaled.append(scaler_savgol[i].fit_transform(savgol_cropped[i].reshape(-1,1)))

savgol_scaled = np.array(savgol_scaled)

X_input = list()
y_input = list()

for savgol in savgol_scaled:
    X_input.append(savgol[:-y.shape[1]])
    y_input.append(savgol[-y.shape[1]:])

X_input = np.array(X_input)
y_input = np.array(y_input)

# %% [markdown]
# ## Main model

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, Conv1D, AveragePooling1D, Flatten, Reshape, SimpleRNN, GRU, MaxPooling1D, concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.initializers import Zeros

inputs = Input(shape=(input_period, num_features))

model_cnn = Sequential([
    Conv1D(filters=352, kernel_size=1, activation='relu'),
    Conv1D(filters=352, kernel_size=1, activation='relu'),
    MaxPooling1D(pool_size=3),
    Dense(units=128),
    Flatten()
    #Dense(units=output_step),
    #Reshape((output_step,1))
])

model_bilstm = Sequential([
    Bidirectional(LSTM(units=384, return_sequences=True, activation='tanh', recurrent_activation='sigmoid')),
    Dropout(0.2),
    Flatten()
    #Dense(units=output_step),
    #Reshape((output_step,1))
])

model_bigru = Sequential([
    Bidirectional(GRU(units=128, activation='tanh', return_sequences=True)),
    Dropout(0.4),
    Flatten()
])

model_multilayer_lstm = Sequential([
    LSTM(units=64, return_sequences=True, activation='tanh', recurrent_activation='sigmoid'),
    Dropout(0.2),
    LSTM(units=64, return_sequences=True, activation='tanh', recurrent_activation='sigmoid'),
    Flatten()
])
# Out:
# 2024-05-31 07:40:42.939227: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-31 07:40:43.412774: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-31 07:40:43.412986: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-31 07:40:43.491470: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-31 07:40:43.718774: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-31 07:40:46.290278: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
output_cnn = model_cnn(inputs)
output_bilstm = model_bilstm(inputs)
output_bigru = model_bigru(inputs)
output_multilayer_lstm = model_multilayer_lstm(inputs)

concatenated_outputs = concatenate([output_cnn, output_bilstm, output_bigru, output_multilayer_lstm])

main_model = Sequential([
    Input(shape=(concatenated_outputs.shape[1],)),
    Dense(units=output_step),
    Reshape((output_step,1))
])

final_output = main_model(concatenated_outputs)

functional_pipeline = Model(inputs=inputs, outputs=final_output)

# %%
# Compile the pipeline model
functional_pipeline.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

checkpoint = ModelCheckpoint(filepath='model_weights_6_5_topological_trend/model_weights_epoch_{epoch:02d}.h5', 
                            save_best_only=True, save_weights_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the pipeline model
history = functional_pipeline.fit(X_input, y_input, epochs=150, batch_size=64, validation_split=0.2, callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/150
# 2024-05-31 07:41:31.821575: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 11796480 exceeds 10% of free system memory.
# 2024-05-31 07:41:31.828551: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 11796480 exceeds 10% of free system memory.
# 2024-05-31 07:41:31.853377: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 17367040 exceeds 10% of free system memory.
# 2024-05-31 07:41:31.879278: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 17367040 exceeds 10% of free system memory.
# 2024-05-31 07:41:32.013551: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 11796480 exceeds 10% of free system memory.
# 44/44 [==============================] - 79s 1s/step - loss: 0.1050 - accuracy: 0.0664 - val_loss: 0.0235 - val_accuracy: 0.0818
# Epoch 2/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0179 - accuracy: 0.0800 - val_loss: 0.0169 - val_accuracy: 0.0828
# Epoch 3/150
# 44/44 [==============================] - 49s 1s/step - loss: 0.0141 - accuracy: 0.0800 - val_loss: 0.0130 - val_accuracy: 0.0830
# Epoch 4/150
# 44/44 [==============================] - 52s 1s/step - loss: 0.0110 - accuracy: 0.0802 - val_loss: 0.0119 - val_accuracy: 0.0830
# Epoch 5/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0089 - accuracy: 0.0803 - val_loss: 0.0084 - val_accuracy: 0.0830
# Epoch 6/150
# 44/44 [==============================] - 51s 1s/step - loss: 0.0071 - accuracy: 0.0804 - val_loss: 0.0066 - val_accuracy: 0.0832
# Epoch 7/150
# 44/44 [==============================] - 49s 1s/step - loss: 0.0060 - accuracy: 0.0805 - val_loss: 0.0074 - val_accuracy: 0.0832
# Epoch 8/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0048 - accuracy: 0.0805 - val_loss: 0.0052 - val_accuracy: 0.0832
# Epoch 9/150
# 44/44 [==============================] - 49s 1s/step - loss: 0.0040 - accuracy: 0.0805 - val_loss: 0.0053 - val_accuracy: 0.0832
# Epoch 10/150
# 44/44 [==============================] - 52s 1s/step - loss: 0.0039 - accuracy: 0.0805 - val_loss: 0.0041 - val_accuracy: 0.0832
# Epoch 11/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0032 - accuracy: 0.0805 - val_loss: 0.0032 - val_accuracy: 0.0832
# Epoch 12/150
# 44/44 [==============================] - 51s 1s/step - loss: 0.0026 - accuracy: 0.0805 - val_loss: 0.0025 - val_accuracy: 0.0832
# Epoch 13/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0023 - accuracy: 0.0805 - val_loss: 0.0025 - val_accuracy: 0.0832
# Epoch 14/150
# 44/44 [==============================] - 52s 1s/step - loss: 0.0023 - accuracy: 0.0805 - val_loss: 0.0032 - val_accuracy: 0.0832
# Epoch 15/150
# 44/44 [==============================] - 52s 1s/step - loss: 0.0021 - accuracy: 0.0805 - val_loss: 0.0022 - val_accuracy: 0.0832
# Epoch 16/150
# 44/44 [==============================] - 53s 1s/step - loss: 0.0018 - accuracy: 0.0805 - val_loss: 0.0019 - val_accuracy: 0.0832
# Epoch 17/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0020 - accuracy: 0.0805 - val_loss: 0.0026 - val_accuracy: 0.0832
# Epoch 18/150
# 44/44 [==============================] - 51s 1s/step - loss: 0.0019 - accuracy: 0.0805 - val_loss: 0.0017 - val_accuracy: 0.0832
# Epoch 19/150
# 44/44 [==============================] - 52s 1s/step - loss: 0.0017 - accuracy: 0.0805 - val_loss: 0.0016 - val_accuracy: 0.0832
# Epoch 20/150
# 44/44 [==============================] - 52s 1s/step - loss: 0.0018 - accuracy: 0.0805 - val_loss: 0.0026 - val_accuracy: 0.0832
# Epoch 21/150
# 44/44 [==============================] - 55s 1s/step - loss: 0.0016 - accuracy: 0.0805 - val_loss: 0.0018 - val_accuracy: 0.0832
# Epoch 22/150
# 44/44 [==============================] - 53s 1s/step - loss: 0.0013 - accuracy: 0.0805 - val_loss: 0.0020 - val_accuracy: 0.0832
# Epoch 23/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0016 - accuracy: 0.0805 - val_loss: 0.0017 - val_accuracy: 0.0832
# Epoch 24/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0015 - accuracy: 0.0805 - val_loss: 0.0012 - val_accuracy: 0.0832
# Epoch 25/150
# 44/44 [==============================] - 48s 1s/step - loss: 0.0014 - accuracy: 0.0805 - val_loss: 0.0014 - val_accuracy: 0.0832
# Epoch 26/150
# 44/44 [==============================] - 49s 1s/step - loss: 0.0012 - accuracy: 0.0805 - val_loss: 0.0014 - val_accuracy: 0.0832
# Epoch 27/150
# 44/44 [==============================] - 51s 1s/step - loss: 0.0012 - accuracy: 0.0805 - val_loss: 0.0013 - val_accuracy: 0.0832
# Epoch 28/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0011 - accuracy: 0.0805 - val_loss: 0.0012 - val_accuracy: 0.0832
# Epoch 29/150
# 44/44 [==============================] - 51s 1s/step - loss: 0.0011 - accuracy: 0.0805 - val_loss: 0.0015 - val_accuracy: 0.0832
# Epoch 30/150
# 44/44 [==============================] - 51s 1s/step - loss: 0.0012 - accuracy: 0.0805 - val_loss: 0.0015 - val_accuracy: 0.0832
# Epoch 31/150
# 44/44 [==============================] - 51s 1s/step - loss: 0.0012 - accuracy: 0.0805 - val_loss: 9.2480e-04 - val_accuracy: 0.0832
# Epoch 32/150
# 44/44 [==============================] - 50s 1s/step - loss: 0.0010 - accuracy: 0.0805 - val_loss: 0.0019 - val_accuracy: 0.0832
# Epoch 33/150
# 44/44 [==============================] - 51s 1s/step - loss: 0.0013 - accuracy: 0.0805 - val_loss: 0.0017 - val_accuracy: 0.0832
# Epoch 34/150
# 44/44 [==============================] - 47s 1s/step - loss: 0.0013 - accuracy: 0.0805 - val_loss: 9.0136e-04 - val_accuracy: 0.0832
# Epoch 35/150
# 44/44 [==============================] - 50s 1s/step - loss: 9.0780e-04 - accuracy: 0.0805 - val_loss: 0.0011 - val_accuracy: 0.0832
# Epoch 36/150
# 44/44 [==============================] - 47s 1s/step - loss: 0.0014 - accuracy: 0.0805 - val_loss: 0.0021 - val_accuracy: 0.0832
# Epoch 37/150
# 44/44 [==============================] - 49s 1s/step - loss: 0.0013 - accuracy: 0.0805 - val_loss: 8.2754e-04 - val_accuracy: 0.0832
# Epoch 38/150
# 44/44 [==============================] - 49s 1s/step - loss: 8.6586e-04 - accuracy: 0.0805 - val_loss: 9.5988e-04 - val_accuracy: 0.0832
# Epoch 39/150
# 44/44 [==============================] - 50s 1s/step - loss: 7.6910e-04 - accuracy: 0.0805 - val_loss: 0.0013 - val_accuracy: 0.0832
# Epoch 40/150
# 44/44 [==============================] - 48s 1s/step - loss: 8.9995e-04 - accuracy: 0.0805 - val_loss: 9.9507e-04 - val_accuracy: 0.0832
# Epoch 41/150
# 44/44 [==============================] - 46s 1s/step - loss: 8.2978e-04 - accuracy: 0.0805 - val_loss: 8.1852e-04 - val_accuracy: 0.0832
# Epoch 42/150
# 44/44 [==============================] - 47s 1s/step - loss: 8.1625e-04 - accuracy: 0.0805 - val_loss: 0.0010 - val_accuracy: 0.0832
# Epoch 43/150
# 44/44 [==============================] - 47s 1s/step - loss: 8.4678e-04 - accuracy: 0.0805 - val_loss: 9.6574e-04 - val_accuracy: 0.0832
# Epoch 44/150
# 44/44 [==============================] - 50s 1s/step - loss: 8.6508e-04 - accuracy: 0.0805 - val_loss: 9.2688e-04 - val_accuracy: 0.0832
# Epoch 45/150
# 44/44 [==============================] - 47s 1s/step - loss: 8.3884e-04 - accuracy: 0.0805 - val_loss: 9.9503e-04 - val_accuracy: 0.0832
# Epoch 46/150
# 44/44 [==============================] - 48s 1s/step - loss: 0.0010 - accuracy: 0.0805 - val_loss: 8.7935e-04 - val_accuracy: 0.0832
# Epoch 47/150
# 44/44 [==============================] - 48s 1s/step - loss: 8.1732e-04 - accuracy: 0.0805 - val_loss: 7.6331e-04 - val_accuracy: 0.0832
# Epoch 48/150
# 44/44 [==============================] - 47s 1s/step - loss: 7.4804e-04 - accuracy: 0.0805 - val_loss: 0.0011 - val_accuracy: 0.0832
# Epoch 49/150
# 44/44 [==============================] - 51s 1s/step - loss: 8.6343e-04 - accuracy: 0.0805 - val_loss: 7.1920e-04 - val_accuracy: 0.0832
# Epoch 50/150
# 44/44 [==============================] - 52s 1s/step - loss: 7.2805e-04 - accuracy: 0.0805 - val_loss: 9.2423e-04 - val_accuracy: 0.0832
# Epoch 51/150
# 44/44 [==============================] - 50s 1s/step - loss: 6.8483e-04 - accuracy: 0.0805 - val_loss: 0.0013 - val_accuracy: 0.0832
# Epoch 52/150
# 44/44 [==============================] - 51s 1s/step - loss: 8.3202e-04 - accuracy: 0.0805 - val_loss: 9.2114e-04 - val_accuracy: 0.0832
# Epoch 53/150
# 44/44 [==============================] - 49s 1s/step - loss: 7.5853e-04 - accuracy: 0.0805 - val_loss: 7.2161e-04 - val_accuracy: 0.0832
# Epoch 54/150
# 44/44 [==============================] - 48s 1s/step - loss: 6.8313e-04 - accuracy: 0.0805 - val_loss: 9.1109e-04 - val_accuracy: 0.0832
# Epoch 55/150
# 44/44 [==============================] - 51s 1s/step - loss: 6.9097e-04 - accuracy: 0.0805 - val_loss: 7.0243e-04 - val_accuracy: 0.0832
# Epoch 56/150
# 44/44 [==============================] - 49s 1s/step - loss: 7.1411e-04 - accuracy: 0.0805 - val_loss: 8.7561e-04 - val_accuracy: 0.0832
# Epoch 57/150
# 44/44 [==============================] - 48s 1s/step - loss: 6.7921e-04 - accuracy: 0.0805 - val_loss: 8.6517e-04 - val_accuracy: 0.0832
# Epoch 58/150
# 44/44 [==============================] - 47s 1s/step - loss: 8.2354e-04 - accuracy: 0.0805 - val_loss: 8.3463e-04 - val_accuracy: 0.0832
# Epoch 59/150
# 44/44 [==============================] - 50s 1s/step - loss: 6.0555e-04 - accuracy: 0.0805 - val_loss: 9.0825e-04 - val_accuracy: 0.0832
# Epoch 60/150
# 44/44 [==============================] - 47s 1s/step - loss: 6.5296e-04 - accuracy: 0.0805 - val_loss: 6.3054e-04 - val_accuracy: 0.0832
# Epoch 61/150
# 44/44 [==============================] - 50s 1s/step - loss: 7.1003e-04 - accuracy: 0.0805 - val_loss: 0.0017 - val_accuracy: 0.0832
# Epoch 62/150
# 44/44 [==============================] - 50s 1s/step - loss: 8.5009e-04 - accuracy: 0.0805 - val_loss: 8.2857e-04 - val_accuracy: 0.0832
# Epoch 63/150
# 44/44 [==============================] - 48s 1s/step - loss: 7.3557e-04 - accuracy: 0.0805 - val_loss: 6.4369e-04 - val_accuracy: 0.0832
# Epoch 64/150
# 44/44 [==============================] - 51s 1s/step - loss: 7.1419e-04 - accuracy: 0.0805 - val_loss: 7.8917e-04 - val_accuracy: 0.0832
# Epoch 65/150
# 44/44 [==============================] - 49s 1s/step - loss: 8.8457e-04 - accuracy: 0.0805 - val_loss: 0.0011 - val_accuracy: 0.0832
# Epoch 66/150
# 44/44 [==============================] - 50s 1s/step - loss: 6.7900e-04 - accuracy: 0.0805 - val_loss: 0.0010 - val_accuracy: 0.0832
# Epoch 67/150
# 44/44 [==============================] - 49s 1s/step - loss: 6.9646e-04 - accuracy: 0.0805 - val_loss: 7.3296e-04 - val_accuracy: 0.0832
# Epoch 68/150
# 44/44 [==============================] - 47s 1s/step - loss: 6.0147e-04 - accuracy: 0.0805 - val_loss: 5.2241e-04 - val_accuracy: 0.0832
# Epoch 69/150
# 44/44 [==============================] - 50s 1s/step - loss: 5.9396e-04 - accuracy: 0.0805 - val_loss: 9.0416e-04 - val_accuracy: 0.0832
# Epoch 70/150
# 44/44 [==============================] - 48s 1s/step - loss: 6.1525e-04 - accuracy: 0.0805 - val_loss: 5.5049e-04 - val_accuracy: 0.0832
# Epoch 71/150
# 44/44 [==============================] - 48s 1s/step - loss: 5.6467e-04 - accuracy: 0.0805 - val_loss: 7.6801e-04 - val_accuracy: 0.0832
# Epoch 72/150
# 44/44 [==============================] - 48s 1s/step - loss: 6.5558e-04 - accuracy: 0.0805 - val_loss: 5.3370e-04 - val_accuracy: 0.0832
# Epoch 73/150
# 44/44 [==============================] - 47s 1s/step - loss: 5.5551e-04 - accuracy: 0.0805 - val_loss: 6.3327e-04 - val_accuracy: 0.0832
# Epoch 74/150
# 44/44 [==============================] - 47s 1s/step - loss: 6.5960e-04 - accuracy: 0.0805 - val_loss: 5.4840e-04 - val_accuracy: 0.0832
# Epoch 75/150
# 44/44 [==============================] - 48s 1s/step - loss: 5.4839e-04 - accuracy: 0.0805 - val_loss: 0.0013 - val_accuracy: 0.0832
# Epoch 76/150
# 44/44 [==============================] - 46s 1s/step - loss: 8.1746e-04 - accuracy: 0.0805 - val_loss: 6.8233e-04 - val_accuracy: 0.0832
# Epoch 77/150
# 44/44 [==============================] - 49s 1s/step - loss: 5.8941e-04 - accuracy: 0.0805 - val_loss: 8.3566e-04 - val_accuracy: 0.0832
# Epoch 78/150
# 44/44 [==============================] - 48s 1s/step - loss: 7.4399e-04 - accuracy: 0.0805 - val_loss: 8.4963e-04 - val_accuracy: 0.0832

# %%
# Select the epoch
best_epoch = np.argmin(history.history['val_loss'])
best_epoch = best_epoch+1
print(f'best result is for epoch number {best_epoch}')

# Load the weights of the model at the chosen epoch
functional_pipeline.load_weights(f'model_weights_6_5_topological_trend/model_weights_epoch_{best_epoch:02d}.h5')
print('Weigths for the best epoch has been loaded.')
# Out:
# best result is for epoch number 68
# Weigths for the best epoch has been loaded.

# %%
best_epoch_backup = 68

# Load the weights of the model at the chosen epoch
functional_pipeline.load_weights(f'model_weights_6_5_topological_trend/model_weights_epoch_{best_epoch_backup:02d}.h5')
print('Backup: Weigths for the best epoch has been loaded.')
# Out:
# Backup: Weigths for the best epoch has been loaded.

# %% [markdown]
# ## data testing

# %%
data_backup = pd.read_csv('data/^NDX_raw_data.csv')
data_backup.rename(columns={'Date': 'date', 'Open':'open', 'High':'high', 'Low':'low', 'Close':'close', 'Volume':'volume'}, inplace=True)

data_backup_copy = data_backup.copy()

# %%
X_test, y_test = create_dataset(data_backup[['close']].to_numpy(), time_step=period, output_step=output_step)

# %%
from scipy.signal import savgol_filter

# Apply Savitzky-Golay filter
window_length = 17  # Window length (must be odd)
polyorder = 1      # Polynomial order

data_savgol_test = savgol_filter(X_test, window_length, polyorder)

# %%
savgol_cropped_test = list()

# NO NEED TO CROP
for _savgol in data_savgol_test:
    savgol_cropped_test.append(_savgol)

savgol_cropped_test = np.array(savgol_cropped_test)

from sklearn.preprocessing import MinMaxScaler

scaler_savgol_test = list(MinMaxScaler() for i in range(savgol_cropped_test.shape[0]))
savgol_scaled_test = list()

for i in range(savgol_cropped_test.shape[0]):
    savgol_scaled_test.append(scaler_savgol_test[i].fit_transform(savgol_cropped_test[i].reshape(-1,1)))

savgol_scaled_test = np.array(savgol_scaled_test)

X_input_test = list()
#y_input = list()

for savgol in savgol_scaled_test:
    X_input_test.append(savgol)
    #y_input.append(savgol[-y.shape[1]:])

X_input_test = np.array(X_input_test)
#y_input = np.array(y_input)

# %%
savgol_predictions_test = list()

for j in range(X_input_test.shape[0]):
    if (j+1) % 100 == 0:
        print(j+1)
        
    savgol_predictions_test.append(
        scaler_savgol_test[j].inverse_transform(
            functional_pipeline.predict(X_input_test[j].reshape(savgol_scaled_test[j].shape[1], input_period, num_features), verbose=0)[0].reshape(1,output_step)
        )
    )

savgol_predictions_test = np.array(savgol_predictions_test)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(50, 40))

t = 0

plt.plot(data_backup.index[t+60:t+67], savgol_predictions_test[t][0], color='blue')
plt.plot(data_backup.index[t:t+60], savgol_cropped_test[t], color='black')
plt.plot(data_backup.index[t:t+60], data_backup['close'].iloc[t:t+60], color='red')
